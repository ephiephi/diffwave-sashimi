# %%
import pickle
import pandas as pd
import numpy as np
from IPython.display import Audio
import torch
import torchaudio
from IPython.display import Audio, display
import json

# %%
with open("stats_dns.json") as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data).T.reset_index()
for i in range(len(df)):
    df.at[i, "index"] = df["index"][i].split("s")[1]

# %%
df.head()
# Out:
#    index                pesq                  stoi                OVRL  \
# 0    0.0  1.1472630500793457  -0.03337493425723871   2.468220620052916
# 1  1e-05  1.0970431566238403     0.886102295389454  1.7799777749869954
# 2  1e-06   1.315470576286316     0.897771496579211  2.5268406306571545
# 3  1e-07  1.1047254800796509   0.43877412763032475  2.2035055970718522
# 4  1e-12   1.147261619567871  -0.03337523009968911      2.468246413041
#
#                   SIG       BAK  \
# 0  2.8756926661035522  3.514253
# 1   3.195346325147116  1.706548
# 2  3.0533160456415307  3.363331
# 3   2.536641243189402  3.537061
# 4   2.875715670088545  3.514262
#
#                                          enhance_dir  \
# 0  /data/ephraim/datasets/known_noise/enhanced_di...
# 1  /data/ephraim/datasets/known_noise/enhanced_di...
# 2  /data/ephraim/datasets/known_noise/enhanced_di...
# 3  /data/ephraim/datasets/known_noise/enhanced_di...
# 4  /data/ephraim/datasets/known_noise/enhanced_di...
#
#                                                 args
# 0  Namespace(enhanced_dir='/data/ephraim/datasets...
# 1  Namespace(enhanced_dir='/data/ephraim/datasets...
# 2  Namespace(enhanced_dir='/data/ephraim/datasets...
# 3  Namespace(enhanced_dir='/data/ephraim/datasets...
# 4  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
df["index"] = df["index"].astype(float)

# %%
df = df.sort_values(by=['index'])
df
# Out:
#            index                pesq                  stoi  \
# 0   0.000000e+00  1.1472630500793457  -0.03337493425723871
# 4   1.000000e-12   1.147261619567871  -0.03337523009968911
# 3   1.000000e-07  1.1047254800796509   0.43877412763032475
# 10  5.000000e-07  1.1849614381790161    0.8327368720940865
# 2   1.000000e-06   1.315470576286316     0.897771496579211
# 5   2.000000e-06   1.347015380859375     0.918497396119492
# 6   3.000000e-06   1.345258355140686    0.9198927154219351
# 7   4.000000e-06  1.3123540878295898    0.9186136362739687
# 9   5.000000e-06  1.2998838424682617    0.9163494850841875
# 1   1.000000e-05  1.0970431566238403     0.886102295389454
# 8   5.000000e-05  1.0592610836029053    0.4064589699014862
#
#                   OVRL                 SIG       BAK  \
# 0    2.468220620052916  2.8756926661035522  3.514253
# 4       2.468246413041   2.875715670088545  3.514262
# 3   2.2035055970718522   2.536641243189402  3.537061
# 10  2.4298810541283977  2.9600251658122576  3.360815
# 2   2.5268406306571545  3.0533160456415307  3.363331
# 5    2.474684016780711  3.1773722888789773  3.072572
# 6   2.3043459011252305   3.176438649321588  2.720201
# 7   2.1619162442014135   3.166468546123433  2.371164
# 9    1.967948251865425  3.1644515250591563  2.071406
# 1   1.7799777749869954   3.195346325147116  1.706548
# 8   1.9085553059276736   2.284809606321416  3.780398
#
#                                           enhance_dir  \
# 0   /data/ephraim/datasets/known_noise/enhanced_di...
# 4   /data/ephraim/datasets/known_noise/enhanced_di...
# 3   /data/ephraim/datasets/known_noise/enhanced_di...
# 10  /data/ephraim/datasets/known_noise/enhanced_di...
# 2   /data/ephraim/datasets/known_noise/enhanced_di...
# 5   /data/ephraim/datasets/known_noise/enhanced_di...
# 6   /data/ephraim/datasets/known_noise/enhanced_di...
# 7   /data/ephraim/datasets/known_noise/enhanced_di...
# 9   /data/ephraim/datasets/known_noise/enhanced_di...
# 1   /data/ephraim/datasets/known_noise/enhanced_di...
# 8   /data/ephraim/datasets/known_noise/enhanced_di...
#
#                                                  args
# 0   Namespace(enhanced_dir='/data/ephraim/datasets...
# 4   Namespace(enhanced_dir='/data/ephraim/datasets...
# 3   Namespace(enhanced_dir='/data/ephraim/datasets...
# 10  Namespace(enhanced_dir='/data/ephraim/datasets...
# 2   Namespace(enhanced_dir='/data/ephraim/datasets...
# 5   Namespace(enhanced_dir='/data/ephraim/datasets...
# 6   Namespace(enhanced_dir='/data/ephraim/datasets...
# 7   Namespace(enhanced_dir='/data/ephraim/datasets...
# 9   Namespace(enhanced_dir='/data/ephraim/datasets...
# 1   Namespace(enhanced_dir='/data/ephraim/datasets...
# 8   Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
df.to_csv("5sec.csv")
