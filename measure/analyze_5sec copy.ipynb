# %%
import pickle
import pandas as pd
import numpy as np
from IPython.display import Audio
import torch
import torchaudio
from IPython.display import Audio, display
import json

# %%
with open("stats_dns.json") as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data).T.reset_index()
for i in range(len(df)):
    df.at[i, "index"] = df["index"][i].split("s")[1]

# %%
df.head()
# Out:
#     index                pesq                   stoi                OVRL  \
# 0     0.0  1.1472630500793457   -0.03337493425723871   2.468220620052916
# 1  0.0001  1.1816272735595703     0.9099451441577803  1.7477081316460361
# 2   1e-05  1.4504841566085815     0.9246541387448248   2.335523423969805
# 3   1e-06  1.1007888317108154     0.5526078353040487   2.173893172725138
# 4   1e-07  1.1403069496154785  -0.015273761330887438  2.4957772769301427
#
#                   SIG       BAK  \
# 0  2.8756926661035522  3.514253
# 1   3.066753086529567  1.652947
# 2  2.7759579055826045  3.406991
# 3  2.5367625652410397  3.432904
# 4  2.7681384416288615  3.797664
#
#                                          enhance_dir  \
# 0  /data/ephraim/datasets/known_noise/enhanced_di...
# 1  /data/ephraim/datasets/known_noise/enhanced_di...
# 2  /data/ephraim/datasets/known_noise/enhanced_di...
# 3  /data/ephraim/datasets/known_noise/enhanced_di...
# 4  /data/ephraim/datasets/known_noise/enhanced_di...
#
#                                                 args
# 0  Namespace(enhanced_dir='/data/ephraim/datasets...
# 1  Namespace(enhanced_dir='/data/ephraim/datasets...
# 2  Namespace(enhanced_dir='/data/ephraim/datasets...
# 3  Namespace(enhanced_dir='/data/ephraim/datasets...
# 4  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
df["index"] = df["index"].astype(float)

# %%
df = df.sort_values(by=['index'])
df
# Out:
#            index                pesq                   stoi  \
# 0   0.000000e+00  1.1472630500793457   -0.03337493425723871
# 5   1.000000e-12   1.147262692451477   -0.03337494303686144
# 4   1.000000e-07  1.1403069496154785  -0.015273761330887438
# 11  5.000000e-07  1.1153508424758911    0.18502408147676724
# 3   1.000000e-06  1.1007888317108154     0.5526078353040487
# 6   2.000000e-06  1.1900854110717773     0.7411327479061327
# 7   3.000000e-06  1.1817376613616943     0.7991781090188198
# 8   4.000000e-06    1.19425630569458     0.8305397536910647
# 10  5.000000e-06   1.239207148551941     0.8489190666553974
# 2   1.000000e-05  1.4504841566085815     0.9246541387448248
# 9   5.000000e-05   1.365269660949707     0.9335207324955399
# 1   1.000000e-04  1.1816272735595703     0.9099451441577803
#
#                   OVRL                 SIG       BAK  \
# 0    2.468220620052916  2.8756926661035522  3.514253
# 5   2.4682217176299925  2.8756942227695177  3.514251
# 4   2.4957772769301427  2.7681384416288615  3.797664
# 11  2.3490014660048804  2.6990224959209272  3.610044
# 3    2.173893172725138  2.5367625652410397  3.432904
# 6    2.364981325961782   2.713526835555079  3.526518
# 7    2.350282225422076  2.7322278269680353  3.531478
# 8    2.386073784392084   2.794717247323062  3.530544
# 10   2.289366019690823   2.759556657005121  3.325692
# 2    2.335523423969805  2.7759579055826045  3.406991
# 9   1.8096609643177952  3.1123839294242526  1.765806
# 1   1.7477081316460361   3.066753086529567  1.652947
#
#                                           enhance_dir  \
# 0   /data/ephraim/datasets/known_noise/enhanced_di...
# 5   /data/ephraim/datasets/known_noise/enhanced_di...
# 4   /data/ephraim/datasets/known_noise/enhanced_di...
# 11  /data/ephraim/datasets/known_noise/enhanced_di...
# 3   /data/ephraim/datasets/known_noise/enhanced_di...
# 6   /data/ephraim/datasets/known_noise/enhanced_di...
# 7   /data/ephraim/datasets/known_noise/enhanced_di...
# 8   /data/ephraim/datasets/known_noise/enhanced_di...
# 10  /data/ephraim/datasets/known_noise/enhanced_di...
# 2   /data/ephraim/datasets/known_noise/enhanced_di...
# 9   /data/ephraim/datasets/known_noise/enhanced_di...
# 1   /data/ephraim/datasets/known_noise/enhanced_di...
#
#                                                  args
# 0   Namespace(enhanced_dir='/data/ephraim/datasets...
# 5   Namespace(enhanced_dir='/data/ephraim/datasets...
# 4   Namespace(enhanced_dir='/data/ephraim/datasets...
# 11  Namespace(enhanced_dir='/data/ephraim/datasets...
# 3   Namespace(enhanced_dir='/data/ephraim/datasets...
# 6   Namespace(enhanced_dir='/data/ephraim/datasets...
# 7   Namespace(enhanced_dir='/data/ephraim/datasets...
# 8   Namespace(enhanced_dir='/data/ephraim/datasets...
# 10  Namespace(enhanced_dir='/data/ephraim/datasets...
# 2   Namespace(enhanced_dir='/data/ephraim/datasets...
# 9   Namespace(enhanced_dir='/data/ephraim/datasets...
# 1   Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
df.to_csv("5sec2.csv")
