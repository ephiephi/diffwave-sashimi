# %%
import pickle
import pandas as pd
import numpy as np
from IPython.display import Audio
import torch
import torchaudio
from IPython.display import Audio, display
import json

# %%
with open("stats_dns_1sec.json") as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data).T.reset_index()
for i in range(len(df)):
    df.at[i, "index"] = df["index"][i].split("s")[1]

# %%
df.head()
# Out:
#      index                pesq                  stoi                OVRL  \
# 0      0.0  1.1345103979110718  -0.09240633384903119  2.4459005785011594
# 1   0.0001  1.2579419612884521    0.9704311057807298  1.3920088324947575
# 2  1.2e-05   1.730184555053711    0.9816634702807459  2.0611905394784897
# 3    1e-05  1.7509474754333496     0.980372055623097   2.116123184657044
# 4    1e-06  1.1827915906906128   0.41278056869164104  2.3957430828111406
#
#                   SIG       BAK  \
# 0   2.706995529342027   3.94361
# 1    2.67897226355371  1.468544
# 2  2.7320997026043936  2.905236
# 3  2.7215635788880705  3.073761
# 4   2.769190876555274  3.708897
#
#                                          enhance_dir  \
# 0  /data/ephraim/datasets/known_noise/enhanced_di...
# 1  /data/ephraim/datasets/known_noise/enhanced_di...
# 2  /data/ephraim/datasets/known_noise/enhanced_di...
# 3  /data/ephraim/datasets/known_noise/enhanced_di...
# 4  /data/ephraim/datasets/known_noise/enhanced_di...
#
#                                                 args
# 0  Namespace(enhanced_dir='/data/ephraim/datasets...
# 1  Namespace(enhanced_dir='/data/ephraim/datasets...
# 2  Namespace(enhanced_dir='/data/ephraim/datasets...
# 3  Namespace(enhanced_dir='/data/ephraim/datasets...
# 4  Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
df["index"] = df["index"].astype(float)

# %%
df = df.sort_values(by=['index'])
df
# Out:
#            index                pesq                  stoi  \
# 0   0.000000e+00  1.1345103979110718  -0.09240633384903119
# 6   1.000000e-12  1.1345078945159912  -0.09240636977464142
# 5   1.000000e-07  1.1515707969665527  -0.07526244000535531
# 9   5.000000e-07  1.1514124870300293    0.1805941802610346
# 4   1.000000e-06  1.1827915906906128   0.41278056869164104
# 10  2.000000e-06  1.5764877796173096    0.8716731154590055
# 11  3.000000e-06  1.6587584018707275    0.9449297433278466
# 12  4.000000e-06  1.7926011085510254    0.9674949085586979
# 8   5.000000e-06   1.796764612197876     0.973811015449313
# 3   1.000000e-05  1.7509474754333496     0.980372055623097
# 2   1.200000e-05   1.730184555053711    0.9816634702807459
# 7   5.000000e-05   1.434400200843811    0.9805260719818751
# 1   1.000000e-04  1.2579419612884521    0.9704311057807298
#
#                   OVRL                 SIG       BAK  \
# 0   2.4459005785011594   2.706995529342027   3.94361
# 6   2.4459018655610154  2.7069975317385757  3.943609
# 5   2.4247600253154684  2.6756386993873496  3.930592
# 9   2.3849409955773004  2.7371359438220826  3.807211
# 4   2.3957430828111406   2.769190876555274  3.708897
# 10   2.492098555310404  2.9044061370780816  3.709096
# 11  2.4268987074197352   2.827154194604152  3.674839
# 12   2.330138623466979   2.761653864585881  3.525454
# 8   2.2403478091994926  2.7183898834244116  3.360368
# 3    2.116123184657044  2.7215635788880705  3.073761
# 2   2.0611905394784897  2.7320997026043936  2.905236
# 7   1.5010881468293982  2.7796852687603697  1.671039
# 1   1.3920088324947575    2.67897226355371  1.468544
#
#                                           enhance_dir  \
# 0   /data/ephraim/datasets/known_noise/enhanced_di...
# 6   /data/ephraim/datasets/known_noise/enhanced_di...
# 5   /data/ephraim/datasets/known_noise/enhanced_di...
# 9   /data/ephraim/datasets/known_noise/enhanced_di...
# 4   /data/ephraim/datasets/known_noise/enhanced_di...
# 10  /data/ephraim/datasets/known_noise/enhanced_di...
# 11  /data/ephraim/datasets/known_noise/enhanced_di...
# 12  /data/ephraim/datasets/known_noise/enhanced_di...
# 8   /data/ephraim/datasets/known_noise/enhanced_di...
# 3   /data/ephraim/datasets/known_noise/enhanced_di...
# 2   /data/ephraim/datasets/known_noise/enhanced_di...
# 7   /data/ephraim/datasets/known_noise/enhanced_di...
# 1   /data/ephraim/datasets/known_noise/enhanced_di...
#
#                                                  args
# 0   Namespace(enhanced_dir='/data/ephraim/datasets...
# 6   Namespace(enhanced_dir='/data/ephraim/datasets...
# 5   Namespace(enhanced_dir='/data/ephraim/datasets...
# 9   Namespace(enhanced_dir='/data/ephraim/datasets...
# 4   Namespace(enhanced_dir='/data/ephraim/datasets...
# 10  Namespace(enhanced_dir='/data/ephraim/datasets...
# 11  Namespace(enhanced_dir='/data/ephraim/datasets...
# 12  Namespace(enhanced_dir='/data/ephraim/datasets...
# 8   Namespace(enhanced_dir='/data/ephraim/datasets...
# 3   Namespace(enhanced_dir='/data/ephraim/datasets...
# 2   Namespace(enhanced_dir='/data/ephraim/datasets...
# 7   Namespace(enhanced_dir='/data/ephraim/datasets...
# 1   Namespace(enhanced_dir='/data/ephraim/datasets...

# %%
df.to_csv("1sec.csv")
