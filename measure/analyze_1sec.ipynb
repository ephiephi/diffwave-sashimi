# %%
import pickle
import pandas as pd
import numpy as np
from IPython.display import Audio
import torch
import torchaudio
from IPython.display import Audio, display
import json
import os

# %%
def df_for_snr(snr_path):
    stats_path = os.path.join(snr_path, "stats_dns.json")
    with open(stats_path) as f:
        data = json.load(f)
    df = pd.DataFrame.from_dict(data).T.reset_index()
    for i in range(len(df)):
        df.at[i, "index"] = df["index"][i].split("s")[1]
    df["index"] = df["index"].astype(float)
    df = df.sort_values(by=['index']).reset_index(drop=True)
    df= df.rename(columns={"index": "s"})
    return df

# %%
with open("stats_dns.json") as f:
    data = json.load(f)
df = pd.DataFrame.from_dict(data).T.reset_index()
for i in range(len(df)):
    df.at[i, "index"] = df["index"][i].split("s")[1]

# %%
df.head()
# Out:
#     index                pesq                 stoi                OVRL  \
# 0     0.0  1.3769800662994385  -0.2703065032111802   2.142177101480849
# 1  0.0001  1.4824198484420776   0.9813492809565783   1.552294777575566
# 2   1e-05   1.820321798324585   0.9576200231527991  2.0544754465920634
# 3   1e-06  1.3459926843643188   0.6611528227337669  2.4126319981265882
# 4   2e-05  1.7961351871490479   0.9575616775821296   2.095316451500083
#
#                   SIG       BAK  \
# 0   2.486637466605888  3.564016
# 1   2.929561042325812  1.615795
# 2  2.6544560774445585  2.964854
# 3   2.904862561738831  3.406361
# 4  2.6011522036250465  3.210202
#
#                                          enhance_dir  \
# 0  /data/ephraim/datasets/known_noise/enhanced_di...
# 1  /data/ephraim/datasets/known_noise/enhanced_di...
# 2  /data/ephraim/datasets/known_noise/enhanced_di...
# 3  /data/ephraim/datasets/known_noise/enhanced_di...
# 4  /data/ephraim/datasets/known_noise/enhanced_di...
#
# ...

# %%
df["index"] = df["index"].astype(float)

# %%
df = df.sort_values(by=['index']).reset_index(drop=True)
df
# Out:
#            index                pesq                 stoi                OVRL  \
# 0   0.000000e+00  1.3769800662994385  -0.2703065032111802   2.142177101480849
# 1   5.000000e-08  1.1020622253417969   0.3426649151637315  1.9105219877645103
# 2   5.000000e-07  1.2549898624420166  0.07708645196826469   2.123844454666306
# 3   1.000000e-06  1.3459926843643188   0.6611528227337669  2.4126319981265882
# 4   2.000000e-06  1.1598351001739502   0.5167215189723376  2.2798305212488996
# 5   3.000000e-06   1.646195650100708   0.8842566425509734   2.404575789014415
# 6   4.000000e-06  1.5027108192443848   0.9271910008592226   2.282555218460665
# 7   5.000000e-06  1.6882870197296143   0.9333735243027523  2.4029107637122937
# 8   6.000000e-06  1.2986359596252441   0.9571132250742683   2.251411863167376
# 9   7.000000e-06   1.569523811340332   0.9567216695868349  2.1653521356733405
# 10  8.000000e-06  1.8464949131011963   0.9685353630447396  2.1963036273836107
# ...

# %%
df.to_csv("/data/ephraim/datasets/known_noise/enhanced_diffwave_1sec/1sec.csv")

# %%
df_for_snr("/data/ephraim/datasets/known_noise/enhanced_diffwave_1sec/snr-10/")
# Out:
#           s                pesq                  stoi                OVRL  \
# 0  0.000001  1.1196917295455933   0.46459356590547934  2.6917717778927392
# 1  0.000002  1.0977504253387451    0.3948466299182143  2.4934423183902448
# 2  0.000004  1.1989513635635376   -0.4211109053333114  2.3822767523901915
# 3  0.000006   1.074244499206543   -0.3206746944114102  2.7569448164988337
# 4  0.000008  1.2575594186782837   0.17494566736714176  2.1280549565159634
# 5  0.000010  1.0720592737197876    0.4327696767391401   2.123119288451828
# 6  0.000030  1.1450858116149902    0.3138233287735859  1.8054529192653153
# 7  0.000050  1.1160693168640137  0.022386537471944027   2.571381827460946
#
#                   SIG       BAK  \
# 0  3.0213731609557315  3.817526
# 1   2.850726808774027  3.879128
# 2  2.6805216556324076  3.746175
# 3  3.0908853018224267  4.008623
# 4   2.474186825583557  3.797306
# 5  2.4568472421044407  3.880201
# 6   2.119791627791953  3.784765
# 7  2.8763223510386595  4.000129
#
# ...

# %%
df_for_snr("/data/ephraim/datasets/known_noise/enhanced_diffwave_1sec/sn