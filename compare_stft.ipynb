# %%
import pickle
import pandas as pd
import numpy as np
from IPython.display import Audio
import torch
import torchaudio
from IPython.display import Audio, display
import json

# %%
from scipy import signal
import matplotlib.pyplot as plt
import scipy.io.wavfile as wavfile

# %%
import os
import librosa
import librosa.display
import IPython.display as ipd
import numpy as np
import matplotlib.pyplot as plt

filename = '/data/ephraim/datasets/known_noise/clean_wav/0a196374_nohash_0_4.wav'
x, sr = librosa.load(filename)

import librosa.display                   #explicitly import librosa.display
X = librosa.stft(x)                      #perform short-term fourier transfrom               
Xdb = librosa.amplitude_to_db(abs(X))    #convert an amplitude spectrogram to dB-scaled spectrogram.
plt.figure(figsize=(15, 5))              #initialize the fig size
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
plt.colorbar()

# %%
filename = '/data/ephraim/datasets/known_noise/enhanced_diffwave_1sec/s4e-06/1000k_0.wav'
x, sr = librosa.load(filename)

import librosa.display                   #explicitly import librosa.display
X = librosa.stft(x)                      #perform short-term fourier transfrom               
Xdb = librosa.amplitude_to_db(abs(X))    #convert an amplitude spectrogram to dB-scaled spectrogram.
plt.figure(figsize=(15, 5))              #initialize the fig size
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
plt.colorbar()

# %%
import torch
import torchaudio
from glob import glob

filenames = glob(f'/data/ephraim/datasets/sc09/wavs/*.wav')
f=filenames[1]
noisy_signal_, sr =torchaudio.load(f)
power_x0_a = 1 / noisy_signal_.shape[1] * torch.sum(noisy_signal_**2)
# power_x0_b =  1 / noisy_signal_.shape[1] * torch.sum(noisy_signal_**2)
print(noisy_signal_)
# Out:
# tensor([[-0.0031, -0.0035, -0.0022,  ..., -0.0019, -0.0032, -0.0060]])

# %%
torch.min(noisy_signal_)
# Out:
# tensor(-0.2509)

# %%
torch.min(noisy_signal_)

# %%
print(f)
(noisy_signal_)[0][1000:1300]
# Out:
# /data/ephraim/datasets/sc09/wavs/004ae714_nohash_1.wav
# tensor([-2.6550e-03, -1.0681e-03, -1.9836e-03, -3.6926e-03, -4.0894e-03,
#         -3.5095e-03, -1.4954e-03, -8.5449e-04, -1.9226e-03, -2.2583e-03,
#         -2.4109e-03, -2.1057e-03, -3.0518e-03, -3.2043e-03, -2.6550e-03,
#         -2.2278e-03, -2.1667e-03, -2.3804e-03, -1.8616e-03, -2.5024e-03,
#         -1.8005e-03, -2.2888e-03, -2.2583e-03, -2.1973e-03, -3.4790e-03,
#         -2.5024e-03, -2.3193e-03, -1.0681e-03, -3.9673e-04, -1.8616e-03,
#         -2.5940e-03, -1.4954e-03, -1.0681e-03, -1.9531e-03, -1.9226e-03,
#         -2.5940e-03, -1.7395e-03, -2.5024e-03, -3.1433e-03, -1.4038e-03,
