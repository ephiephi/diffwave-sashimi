# %%
import pickle
import pandas as pd
import numpy as np
from IPython.display import Audio
import torch
import torchaudio
from IPython.display import Audio, display
import json
import torch
import torchaudio
from glob import glob

# %%
from scipy import signal
import matplotlib.pyplot as plt
import scipy.io.wavfile as wavfile



import os
import librosa
import librosa.display
import IPython.display as ipd
import numpy as np
import matplotlib.pyplot as plt

# %%
filename = '/data/ephraim/datasets/known_noise/clean_wav/0a196374_nohash_0_4.wav'
x, sr = librosa.load(filename)

import librosa.display                   #explicitly import librosa.display
X = librosa.stft(x)                      #perform short-term fourier transfrom               
Xdb = librosa.amplitude_to_db(abs(X))    #convert an amplitude spectrogram to dB-scaled spectrogram.
plt.figure(figsize=(15, 5))              #initialize the fig size
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
plt.colorbar()

# %%
filename = '/data/ephraim/datasets/known_noise/enhanced_diffwave_1sec/s4e-06/1000k_0.wav'
x, sr = librosa.load(filename)

import librosa.display                   #explicitly import librosa.display
X = librosa.stft(x)                      #perform short-term fourier transfrom               
Xdb = librosa.amplitude_to_db(abs(X))    #convert an amplitude spectrogram to dB-scaled spectrogram.
plt.figure(figsize=(15, 5))              #initialize the fig size
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
plt.colorbar()

# %%
filenames = glob(f'/data/ephraim/datasets/sc09/wavs/*.wav')
f=filenames[1]
noisy_signal_, sr =torchaudio.load(f)
power_x0_a = 1 / noisy_signal_.shape[1] * torch.sum(noisy_signal_**2)
# power_x0_b =  1 / noisy_signal_.shape[1] * torch.sum(noisy_signal_**2)
print(noisy_signal_)
# Out:
# tensor([[-0.0031, -0.0035, -0.0022,  ..., -0.0019, -0.0032, -0.0060]])

# %%
filename = '/data/ephraim/datasets/known_noise/enhanced_diffwave_1sec/snr10/s9e-06/1000k_0.wav'
x, sr = librosa.load(filename)

import librosa.display                   #explicitly import librosa.display
X = librosa.stft(x)                      #perform short-term fourier transfrom               
Xdb = librosa.amplitude_to_db(abs(X))    #convert an amplitude spectrogram to dB-scaled spectrogram.
plt.figure(figsize=(15, 5))              #initialize the fig size
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
plt.colorbar()

# %%
from audio_tools2 import plot_specgram, plot_waveform, print_stats

# %%
f = '/data/ephraim/datasets/known_noise/enhanced_diffwave_1sec/snr10/s9e-06/1000k_0.wav'
noisy_signal_, sr =torchaudio.load(f)
plot_specgram(noisy_signal_, sr)

# %%
f = '/data/ephraim/datasets/known_noise/bad_power/enhanced_diffwave_1sec/s4e-06/1000k_0.wav'
noisy_signal_, sr =torchaudio.load(f)
plot_specgram(noisy_signal_, sr)

# %%
f = '/data/ephraim/datasets/known_noise/clean_wav/0a196374_nohash_0_4.wav'
noisy_signal_, sr =torchaudio.load(f)
plot_specgram(noisy_signal_, sr)

# %%
f = '/data/ephraim/datasets/known_noise/noisy_wav/digits_snr10_var0.00047484078095294535.wav'
noisy_signal_, sr =torchaudio.load(f)
# noisy_signal_[:,0:16000].shape

plot_specgram(noisy_signal_[:,0:16000], sr)
